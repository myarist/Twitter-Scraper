# %%
import os
import tweepy as tw
import pandas as pd

consumer_key        = 'consumer_key'
consumer_secret     = 'consumer_secret'
access_token        = 'access_token'
access_token_secret = 'access_token_secret'

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth,wait_on_rate_limit = True)

search_words = "Corona"
new_search   = search_words + " -filter:retweets"

tweets = tw.Cursor(api.search, 
                   q                = new_search,
                   result_type      = "mixed",
                   lang             = "id",
                   count            = 100,
                   include_entities = True,
                   since_id         = "2020-01-01").items(2000)

users_locs = [[tweet.created_at,
               tweet.author.screen_name,
               tweet.author.name,
               tweet.text,
               tweet.retweet_count,
               tweet.favorite_count,
               tweet.user.location] for tweet in tweets]

tweet_text = pd.DataFrame(data = users_locs, 
                          columns = ["date",
                                     "user",
                                     "name",
                                     "text",
                                     "retweet",
                                     "favorite",
                                     "location"])

# %%
tweet_text.to_csv("{}.csv".format(search_words), index = False, header = True)
tweet_text.to_excel("{}.xlsx".format(search_words), index = False)
tweet_text
# Out:
#                     date             user                 name  \
# 0    2020-06-18 14:11:56         wachidnz     wachid nur zidiq
# 1    2020-06-18 14:11:55      sunnycroser                Sunny
# 2    2020-06-18 14:11:53       ReadOneRay      DensReadOneRay♚
# 3    2020-06-18 14:11:42    Cherylrosie27                 Anne
# 4    2020-06-18 14:11:33          mirqals                 drac
# ...                  ...              ...                  ...
# 1995 2020-06-18 11:39:31      fahiraidris  Fahira Idris DPD RI
# 1996 2020-06-18 11:39:28        hayateey1              Doyenne
# 1997 2020-06-18 11:39:27       hangyuliec                ًacha
# 1998 2020-06-18 11:39:19  adriankusaihir1    adriankusaihiride
# 1999 2020-06-18 11:39:17      danielnaimx                    😈
#
#                                                    text  retweet  favorite  \
# 0     @firdzaradiany Hari ini rekor positif corona d...        0         0
# 1                  Kya kiss krny sy corona phelta hy???        0         0
# 2     Beli corona tinggal terapkan strategi sosial d...        0         0
# 3         Kapan corona kelar sih pengen pulang akutuh😭😭        0         0
# 4        Nur Corona Sanitiziyah https://t.co/HODnedOsU7        0         0
# ...                                                 ...      ...       ...
# 1995  Sebagai denyut nadi dan penggerak utama pereko...        1        10
# 1996  @__balqeesaah @Maymunatou2 Toh an bi an dameni...        0         1
# 1997                                corona kpan selesai        0         0
# 1998  @AgusSud15499737 @KBewok6 @LisaAmartatara3 @Na...        0         0
# 1999  jauhi corona dekati abang https://t.co/HEJFoLFQWP        0        16
#
#                     location
# 0      Semarang, Jawa Tengah
# 1
# 2     Bogor Timur, Indonesia
# 3                 Venice, FL
# 4                         KL
# ...                      ...
# 1995             DKI Jakarta
# 1996            Kano Nigeria
# 1997                      O4
# 1998
# 1999
#
# [2000 rows x 7 columns]
